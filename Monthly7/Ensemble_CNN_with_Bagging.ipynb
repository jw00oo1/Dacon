# %% [markdown]
# <a href="https://colab.research.google.com/github/jw00oo1/Dacon/blob/main/Ensemble_CNN_with_Bagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries & Prepare Dataset

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import Model, Input, layers
from tensorflow.keras.layers import BatchNormalization, Conv2D, concatenate, Flatten, MaxPooling2D, Dropout
from pathlib import Path
from tensorflow.keras.callbacks import ModelCheckpoint
import os
from datetime import datetime
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

data_url = {'train': 'https://bit.ly/34zEKdv',
            'test': 'https://bit.ly/2YGZ0WJ',
            'submission': 'https://bit.ly/3hDT2xi'}

cwd = Path(os.getcwd())

now = datetime.now()

suffix = ''
def set_suffix():
  global suffix
  now = datetime.now()
  year, month, day, hour, minute, second = now.year, now.month, now.day, now.hour, now.minute, now.second
  suffix = f'{year}_{month}_{day}__{hour}_{minute}_{second}'
set_suffix()
suffix
# Out:
# '2020_9_17__13_22_25'

# %%
def check_res():
  global cwd
  if not (cwd / 'res').exists():
    os.mkdir(cwd / 'res')
    for key in data_url.keys():
      download_url = data_url[key]
      from urllib.request import urlopen 
      file = urlopen(download_url)
      file_data = file.read()
      with open(cwd / 'res' / f'{key}.csv', 'wb') as f:
        f.write(file_data)
        f.close()

# %%
check_res()

train_path, test_path = [cwd / 'res' / f'{file}.csv' for file in ['train', 'test']]
train_csv = pd.read_csv(train_path)
test_csv = pd.read_csv(test_path)

# %%
def get_dataset_from_csv(csv: pd.DataFrame, is_test=False, to_sparse=True, only_img=True, preprocessing=True):
    img_key = csv.keys()[(2 if is_test else 3):]
    letters = []
    letter_temp = csv['letter']
    for letter in letter_temp:
        letter = ord(letter) - ord('A')
        if to_sparse:
            temp = np.zeros(26)
            temp[letter] = 1
        letter = np.array(letter)
        letters.append(letter)
    letters = np.array(letters)
    if len(letters.shape) == 1:
        letters = np.expand_dims(letters, axis=-1)
    imgs = np.array(csv[img_key]).reshape(-1, 28, 28, 1)
    if preprocessing:
        imgs[imgs < 128] = 0
    imgs = imgs / 255.
    ret = imgs if only_img else np.append(letters, imgs, axis=1)
    if not is_test:
        ret = ret, np.array(csv['digit'])
    return ret

# %%
train_ds = get_dataset_from_csv(train_csv, to_sparse=False, preprocessing=True)
test_ds = get_dataset_from_csv(test_csv, True, to_sparse=False, preprocessing=False)

x_train, y_train = train_ds
x_test, y_test = test_ds, np.array([-1 for i in range(len(test_ds))])
x_all = np.append(x_train, x_test, axis=0)
y_all = np.append(y_train, y_test, axis=0)

def setup_data():
    global train_ds, test_ds, x_train, y_train, x_test, y_test, x_all, y_all
    train_ds = get_dataset_from_csv(train_csv, to_sparse=False, preprocessing=False)
    test_ds = get_dataset_from_csv(test_csv, True, to_sparse=False, preprocessing=False)

    x_train, y_train = train_ds
    x_test, y_test = test_ds, np.array([-1 for i in range(len(test_ds))])
    x_all = np.append(x_train, x_test, axis=0)
    y_all = np.append(y_train, y_test, axis=0)

# %%
from sklearn.model_selection import train_test_split
setup_data()

validation_split = 0.2

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=validation_split, random_state=2020)

# %%
import tensorflow.keras.layers as layers

def CNN(layer=3):
    img_input = Input(shape=(28,28,1))

    c1_1 = Conv2D(64, kernel_size=3, strides=1, padding='same', activation='relu')(img_input)
    c1_2 = Conv2D(64, kernel_size=3, strides=1, padding='same')(c1_1)
    add1 = layers.add([c1_1, c1_2])
    c1_3 = layers.Activation('relu')(add1)
    output_1 = c1_3
    
    c2_1 = Conv2D(128, kernel_size=3, strides=1, padding='same', activation='relu')(output_1)
    c2_2 = Conv2D(128, kernel_size=3, strides=1, padding='same')(c2_1)
    add2 = layers.add([c2_1, c2_2])
    c2_3 = layers.Activation('relu')(add2)
    output_2 = layers.AvgPool2D(pool_size=2)(c2_3)
    
    c3_1 = Conv2D(256, kernel_size=3, strides=1, padding='same', activation='relu')(output_2)
    c3_2 = Conv2D(256, kernel_size=3, strides=1, padding='same')(c3_1)
    add3 = layers.add([c3_1, c3_2])
    c3_3 = layers.Activation('relu')(add3)
    output_3 = MaxPooling2D(pool_size=2)(c3_3)
    
    if layer == 4:
        c4_1 = Conv2D(256, kernel_size=3, strides=1, padding='same', activation='relu')(output_3)
        c4_2 = Conv2D(256, kernel_size=3, strides=1, padding='same')(c4_1)
        add4 = layers.add([c4_1, c4_2])
        c4_3 = layers.Activation('relu')(add4)
        output_4 = MaxPooling2D(pool_size=2)(c4_3)

    x = Flatten(name='feature_output')(output_3 if layer != 4 else output_4)
    x = Dropout(0.4)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = Dropout(0.4)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dense(10, activation='softmax')(x)

    model = Model(inputs=[img_input], outputs=[x])
    model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0003),
                  loss = 'sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
n_ensemble = 10

model_list = []
for i in range(n_ensemble):
    model = CNN(4)
    model_list.append(model)
model.summary()

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
reduceLR = ReduceLROnPlateau(
    monitor = 'val_loss',
    factor = 0.5,
    patience=10,
)

class StopTraining(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', baseline=0.97):
        self.monitor = monitor
        self.baseline = baseline
    
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        acc = float(logs.get(self.monitor))
        if acc is not None:
            if acc > self.baseline:
                print(f'Epoch {epoch}: {self.monitor} reached {self.baseline}, terminating training')
                self.model.stop_training = True

stop_training = StopTraining(baseline=.98)
setup_data()

epochs = 100
batch_size = 32
validation_split = .2
if not (cwd / 'h5_models').exists():
  os.mkdir(cwd / 'h5_models')
model_path = cwd / 'h5_models'
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=validation_split, random_state=2020)

for i in range(len(model_list)):
    print(f'**********model_{i}*********')
    filename = f'best_model_{i}_{suffix}.h5'
    path = model_path / filename
    mc = ModelCheckpoint(path, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 10, restore_best_weights = True)

    setup_data()
    random_state = np.random.randint(0, 2020)
    print(f'random_state: {random_state}')
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=validation_split, random_state=random_state)
    history = model_list[i].fit(x = x_train, y = y_train, epochs = epochs, batch_size = batch_size,
                       shuffle = True, validation_data = (x_val, y_val), callbacks = [mc, stop_training, reduceLR])
    # model_list[i].load_weights(path)
# Out:
# **********model_0*********
# random_state: 1948
# Epoch 1/100
# 52/52 [==============================] - ETA: 0s - loss: 2.3033 - accuracy: 0.1111
# Epoch 00001: val_loss improved from inf to 2.29153, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 18ms/step - loss: 2.3033 - accuracy: 0.1111 - val_loss: 2.2915 - val_accuracy: 0.1073
# Epoch 2/100
# 48/52 [==========================>...] - ETA: 0s - loss: 2.2730 - accuracy: 0.1432
# Epoch 00002: val_loss improved from 2.29153 to 2.23648, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 2.2732 - accuracy: 0.1429 - val_loss: 2.2365 - val_accuracy: 0.2756
# Epoch 3/100
# 48/52 [==========================>...] - ETA: 0s - loss: 1.9470 - accuracy: 0.2917
# Epoch 00003: val_loss improved from 2.23648 to 1.68739, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 1.9359 - accuracy: 0.2967 - val_loss: 1.6874 - val_accuracy: 0.4659
# Epoch 4/100
# 50/52 [===========================>..] - ETA: 0s - loss: 1.4229 - accuracy: 0.5206
# Epoch 00004: val_loss improved from 1.68739 to 1.12623, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 1.4153 - accuracy: 0.5238 - val_loss: 1.1262 - val_accuracy: 0.5976
# Epoch 5/100
# 48/52 [==========================>...] - ETA: 0s - loss: 1.1171 - accuracy: 0.6335
# Epoch 00005: val_loss improved from 1.12623 to 0.78027, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 24ms/step - loss: 1.1042 - accuracy: 0.6374 - val_loss: 0.7803 - val_accuracy: 0.7390
# Epoch 6/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.8213 - accuracy: 0.7402
# Epoch 00006: val_loss improved from 0.78027 to 0.60373, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8169 - accuracy: 0.7399 - val_loss: 0.6037 - val_accuracy: 0.8098
# Epoch 7/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.6259 - accuracy: 0.7965
# Epoch 00007: val_loss improved from 0.60373 to 0.50517, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 0.6178 - accuracy: 0.7973 - val_loss: 0.5052 - val_accuracy: 0.8317
# Epoch 8/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.4968 - accuracy: 0.8355
# Epoch 00008: val_loss did not improve from 0.50517
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5131 - accuracy: 0.8291 - val_loss: 0.6135 - val_accuracy: 0.7732
# Epoch 9/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.4751 - accuracy: 0.8363
# Epoch 00009: val_loss improved from 0.50517 to 0.44752, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 15ms/step - loss: 0.4777 - accuracy: 0.8352 - val_loss: 0.4475 - val_accuracy: 0.8463
# Epoch 10/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.3856 - accuracy: 0.8619
# Epoch 00010: val_loss improved from 0.44752 to 0.35735, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3908 - accuracy: 0.8596 - val_loss: 0.3574 - val_accuracy: 0.8707
# Epoch 11/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.3460 - accuracy: 0.8835
# Epoch 00011: val_loss did not improve from 0.35735
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3358 - accuracy: 0.8864 - val_loss: 0.3941 - val_accuracy: 0.8561
# Epoch 12/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.2482 - accuracy: 0.9194
# Epoch 00012: val_loss did not improve from 0.35735
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2484 - accuracy: 0.9194 - val_loss: 0.3655 - val_accuracy: 0.8683
# Epoch 13/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.2218 - accuracy: 0.9225
# Epoch 00013: val_loss did not improve from 0.35735
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2198 - accuracy: 0.9225 - val_loss: 0.4169 - val_accuracy: 0.8805
# Epoch 14/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.2042 - accuracy: 0.9254
# Epoch 00014: val_loss improved from 0.35735 to 0.34442, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2054 - accuracy: 0.9249 - val_loss: 0.3444 - val_accuracy: 0.8707
# Epoch 15/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1696 - accuracy: 0.9469
# Epoch 00015: val_loss did not improve from 0.34442
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1732 - accuracy: 0.9451 - val_loss: 0.4607 - val_accuracy: 0.8683
# Epoch 16/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1695 - accuracy: 0.9406
# Epoch 00016: val_loss did not improve from 0.34442
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1679 - accuracy: 0.9414 - val_loss: 0.3979 - val_accuracy: 0.8805
# Epoch 17/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1060 - accuracy: 0.9577
# Epoch 00017: val_loss did not improve from 0.34442
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1139 - accuracy: 0.9585 - val_loss: 0.3961 - val_accuracy: 0.8854
# Epoch 18/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1206 - accuracy: 0.9613
# Epoch 00018: val_loss did not improve from 0.34442
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1188 - accuracy: 0.9621 - val_loss: 0.3492 - val_accuracy: 0.8878
# Epoch 19/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.0980 - accuracy: 0.9674
# Epoch 00019: val_loss improved from 0.34442 to 0.32724, saving model to /content/h5_models/best_model_0_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0974 - accuracy: 0.9676 - val_loss: 0.3272 - val_accuracy: 0.8634
# Epoch 20/100
# 51/52 [============================>.] - ETA: 0s - loss: 0.0750 - accuracy: 0.9749
# Epoch 00020: val_loss did not improve from 0.32724
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0747 - accuracy: 0.9750 - val_loss: 0.3720 - val_accuracy: 0.8805
# Epoch 21/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0877 - accuracy: 0.9668
# Epoch 00021: val_loss did not improve from 0.32724
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0852 - accuracy: 0.9676 - val_loss: 0.4396 - val_accuracy: 0.8951
# Epoch 22/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.0659 - accuracy: 0.9772
# Epoch 00022: val_loss did not improve from 0.32724
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0660 - accuracy: 0.9780 - val_loss: 0.3787 - val_accuracy: 0.9024
# Epoch 23/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0712 - accuracy: 0.9819
# Epoch 00023: val_loss did not improve from 0.32724
# Epoch 22: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0708 - accuracy: 0.9817 - val_loss: 0.4871 - val_accuracy: 0.8780
# **********model_1*********
# random_state: 1241
# Epoch 1/100
# 50/52 [===========================>..] - ETA: 0s - loss: 2.2977 - accuracy: 0.1194
# Epoch 00001: val_loss improved from inf to 2.28264, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 14ms/step - loss: 2.2966 - accuracy: 0.1221 - val_loss: 2.2826 - val_accuracy: 0.1317
# Epoch 2/100
# 47/52 [==========================>...] - ETA: 0s - loss: 2.1518 - accuracy: 0.2168
# Epoch 00002: val_loss improved from 2.28264 to 1.72407, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1216 - accuracy: 0.2265 - val_loss: 1.7241 - val_accuracy: 0.3805
# Epoch 3/100
# 49/52 [===========================>..] - ETA: 0s - loss: 1.7640 - accuracy: 0.3731
# Epoch 00003: val_loss improved from 1.72407 to 1.41733, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.7442 - accuracy: 0.3791 - val_loss: 1.4173 - val_accuracy: 0.5293
# Epoch 4/100
# 46/52 [=========================>....] - ETA: 0s - loss: 1.2991 - accuracy: 0.5686
# Epoch 00004: val_loss improved from 1.41733 to 1.13185, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 1.2858 - accuracy: 0.5702 - val_loss: 1.1318 - val_accuracy: 0.6098
# Epoch 5/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.9330 - accuracy: 0.7009
# Epoch 00005: val_loss improved from 1.13185 to 0.82859, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 24ms/step - loss: 0.9312 - accuracy: 0.6984 - val_loss: 0.8286 - val_accuracy: 0.7366
# Epoch 6/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.7132 - accuracy: 0.7556
# Epoch 00006: val_loss improved from 0.82859 to 0.68517, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 0.7189 - accuracy: 0.7527 - val_loss: 0.6852 - val_accuracy: 0.7537
# Epoch 7/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.5552 - accuracy: 0.8111
# Epoch 00007: val_loss improved from 0.68517 to 0.64788, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.5547 - accuracy: 0.8132 - val_loss: 0.6479 - val_accuracy: 0.7756
# Epoch 8/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.4548 - accuracy: 0.8374
# Epoch 00008: val_loss did not improve from 0.64788
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4535 - accuracy: 0.8370 - val_loss: 0.6730 - val_accuracy: 0.7878
# Epoch 9/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.3960 - accuracy: 0.8667
# Epoch 00009: val_loss improved from 0.64788 to 0.53491, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 17ms/step - loss: 0.3864 - accuracy: 0.8712 - val_loss: 0.5349 - val_accuracy: 0.8073
# Epoch 10/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.3767 - accuracy: 0.8743
# Epoch 00010: val_loss improved from 0.53491 to 0.53330, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3733 - accuracy: 0.8755 - val_loss: 0.5333 - val_accuracy: 0.8146
# Epoch 11/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.3226 - accuracy: 0.8969
# Epoch 00011: val_loss did not improve from 0.53330
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3177 - accuracy: 0.8974 - val_loss: 0.5573 - val_accuracy: 0.8122
# Epoch 12/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.2483 - accuracy: 0.9178
# Epoch 00012: val_loss improved from 0.53330 to 0.52066, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 16ms/step - loss: 0.2459 - accuracy: 0.9212 - val_loss: 0.5207 - val_accuracy: 0.8268
# Epoch 13/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.1931 - accuracy: 0.9368
# Epoch 00013: val_loss did not improve from 0.52066
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1967 - accuracy: 0.9371 - val_loss: 0.6195 - val_accuracy: 0.8366
# Epoch 14/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.2075 - accuracy: 0.9228
# Epoch 00014: val_loss did not improve from 0.52066
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2030 - accuracy: 0.9255 - val_loss: 0.5776 - val_accuracy: 0.8390
# Epoch 15/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1523 - accuracy: 0.9419
# Epoch 00015: val_loss improved from 0.52066 to 0.50609, saving model to /content/h5_models/best_model_1_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1558 - accuracy: 0.9408 - val_loss: 0.5061 - val_accuracy: 0.8463
# Epoch 16/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1811 - accuracy: 0.9381
# Epoch 00016: val_loss did not improve from 0.50609
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1775 - accuracy: 0.9396 - val_loss: 0.5836 - val_accuracy: 0.8171
# Epoch 17/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1074 - accuracy: 0.9644
# Epoch 00017: val_loss did not improve from 0.50609
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1104 - accuracy: 0.9628 - val_loss: 0.5965 - val_accuracy: 0.8512
# Epoch 18/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.0871 - accuracy: 0.9688
# Epoch 00018: val_loss did not improve from 0.50609
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0851 - accuracy: 0.9695 - val_loss: 0.7398 - val_accuracy: 0.8512
# Epoch 19/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1433 - accuracy: 0.9506
# Epoch 00019: val_loss did not improve from 0.50609
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1443 - accuracy: 0.9499 - val_loss: 0.5243 - val_accuracy: 0.8439
# Epoch 20/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0825 - accuracy: 0.9688
# Epoch 00020: val_loss did not improve from 0.50609
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0798 - accuracy: 0.9701 - val_loss: 0.6746 - val_accuracy: 0.8293
# Epoch 21/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0604 - accuracy: 0.9815
# Epoch 00021: val_loss did not improve from 0.50609
# Epoch 20: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0586 - accuracy: 0.9817 - val_loss: 0.6078 - val_accuracy: 0.8537
# **********model_2*********
# random_state: 1113
# Epoch 1/100
# 50/52 [===========================>..] - ETA: 0s - loss: 2.3033 - accuracy: 0.1075
# Epoch 00001: val_loss improved from inf to 2.28876, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 15ms/step - loss: 2.3037 - accuracy: 0.1062 - val_loss: 2.2888 - val_accuracy: 0.1122
# Epoch 2/100
# 48/52 [==========================>...] - ETA: 0s - loss: 2.2246 - accuracy: 0.1855
# Epoch 00002: val_loss improved from 2.28876 to 2.01544, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2156 - accuracy: 0.1880 - val_loss: 2.0154 - val_accuracy: 0.3049
# Epoch 3/100
# 50/52 [===========================>..] - ETA: 0s - loss: 1.8788 - accuracy: 0.3381
# Epoch 00003: val_loss improved from 2.01544 to 1.50250, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.8741 - accuracy: 0.3400 - val_loss: 1.5025 - val_accuracy: 0.4659
# Epoch 4/100
# 49/52 [===========================>..] - ETA: 0s - loss: 1.3679 - accuracy: 0.5198
# Epoch 00004: val_loss improved from 1.50250 to 1.01223, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 1.3572 - accuracy: 0.5250 - val_loss: 1.0122 - val_accuracy: 0.6390
# Epoch 5/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.9783 - accuracy: 0.6677
# Epoch 00005: val_loss improved from 1.01223 to 0.88229, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 13ms/step - loss: 0.9771 - accuracy: 0.6685 - val_loss: 0.8823 - val_accuracy: 0.7146
# Epoch 6/100
# 51/52 [============================>.] - ETA: 0s - loss: 0.7945 - accuracy: 0.7359
# Epoch 00006: val_loss improved from 0.88229 to 0.66518, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.7940 - accuracy: 0.7363 - val_loss: 0.6652 - val_accuracy: 0.7659
# Epoch 7/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.6355 - accuracy: 0.7930
# Epoch 00007: val_loss improved from 0.66518 to 0.57274, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6334 - accuracy: 0.7937 - val_loss: 0.5727 - val_accuracy: 0.8146
# Epoch 8/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.5676 - accuracy: 0.8172
# Epoch 00008: val_loss improved from 0.57274 to 0.53194, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 0.5636 - accuracy: 0.8193 - val_loss: 0.5319 - val_accuracy: 0.8293
# Epoch 9/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.4292 - accuracy: 0.8450
# Epoch 00009: val_loss improved from 0.53194 to 0.45857, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.4258 - accuracy: 0.8462 - val_loss: 0.4586 - val_accuracy: 0.8488
# Epoch 10/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.3918 - accuracy: 0.8644
# Epoch 00010: val_loss did not improve from 0.45857
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3901 - accuracy: 0.8639 - val_loss: 0.4889 - val_accuracy: 0.8537
# Epoch 11/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.3051 - accuracy: 0.9056
# Epoch 00011: val_loss improved from 0.45857 to 0.43897, saving model to /content/h5_models/best_model_2_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3012 - accuracy: 0.9072 - val_loss: 0.4390 - val_accuracy: 0.8610
# Epoch 12/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.2653 - accuracy: 0.9081
# Epoch 00012: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2655 - accuracy: 0.9078 - val_loss: 0.4657 - val_accuracy: 0.8537
# Epoch 13/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.2293 - accuracy: 0.9225
# Epoch 00013: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2269 - accuracy: 0.9237 - val_loss: 0.4560 - val_accuracy: 0.8561
# Epoch 14/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1806 - accuracy: 0.9401
# Epoch 00014: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1779 - accuracy: 0.9408 - val_loss: 0.4745 - val_accuracy: 0.8707
# Epoch 15/100
# 51/52 [============================>.] - ETA: 0s - loss: 0.1721 - accuracy: 0.9387
# Epoch 00015: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 10ms/step - loss: 0.1716 - accuracy: 0.9389 - val_loss: 0.5290 - val_accuracy: 0.8463
# Epoch 16/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1528 - accuracy: 0.9447
# Epoch 00016: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1519 - accuracy: 0.9457 - val_loss: 0.4405 - val_accuracy: 0.8683
# Epoch 17/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1059 - accuracy: 0.9649
# Epoch 00017: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1081 - accuracy: 0.9646 - val_loss: 0.5391 - val_accuracy: 0.8512
# Epoch 18/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1105 - accuracy: 0.9656
# Epoch 00018: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1118 - accuracy: 0.9652 - val_loss: 0.4700 - val_accuracy: 0.8610
# Epoch 19/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1155 - accuracy: 0.9649
# Epoch 00019: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1176 - accuracy: 0.9640 - val_loss: 0.5963 - val_accuracy: 0.8366
# Epoch 20/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1256 - accuracy: 0.9581
# Epoch 00020: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1266 - accuracy: 0.9579 - val_loss: 0.5536 - val_accuracy: 0.8659
# Epoch 21/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.0988 - accuracy: 0.9668
# Epoch 00021: val_loss did not improve from 0.43897
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0998 - accuracy: 0.9658 - val_loss: 0.4928 - val_accuracy: 0.8683
# Epoch 22/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.0590 - accuracy: 0.9811
# Epoch 00022: val_loss did not improve from 0.43897
# Epoch 21: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0559 - accuracy: 0.9823 - val_loss: 0.4562 - val_accuracy: 0.8756
# **********model_3*********
# random_state: 1969
# Epoch 1/100
# 50/52 [===========================>..] - ETA: 0s - loss: 2.3040 - accuracy: 0.1150
# Epoch 00001: val_loss improved from inf to 2.28987, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 15ms/step - loss: 2.3036 - accuracy: 0.1160 - val_loss: 2.2899 - val_accuracy: 0.1073
# Epoch 2/100
# 48/52 [==========================>...] - ETA: 0s - loss: 2.2950 - accuracy: 0.1309
# Epoch 00002: val_loss improved from 2.28987 to 2.18544, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2934 - accuracy: 0.1313 - val_loss: 2.1854 - val_accuracy: 0.1902
# Epoch 3/100
# 48/52 [==========================>...] - ETA: 0s - loss: 1.9698 - accuracy: 0.2917
# Epoch 00003: val_loss improved from 2.18544 to 1.63810, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.9604 - accuracy: 0.2955 - val_loss: 1.6381 - val_accuracy: 0.4390
# Epoch 4/100
# 47/52 [==========================>...] - ETA: 0s - loss: 1.5061 - accuracy: 0.4894
# Epoch 00004: val_loss improved from 1.63810 to 1.26388, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 1.4885 - accuracy: 0.4994 - val_loss: 1.2639 - val_accuracy: 0.5610
# Epoch 5/100
# 51/52 [============================>.] - ETA: 0s - loss: 1.0432 - accuracy: 0.6507
# Epoch 00005: val_loss improved from 1.26388 to 0.93021, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 1.0422 - accuracy: 0.6514 - val_loss: 0.9302 - val_accuracy: 0.7049
# Epoch 6/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.8070 - accuracy: 0.7174
# Epoch 00006: val_loss improved from 0.93021 to 0.79347, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8119 - accuracy: 0.7179 - val_loss: 0.7935 - val_accuracy: 0.7610
# Epoch 7/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.6575 - accuracy: 0.7786
# Epoch 00007: val_loss improved from 0.79347 to 0.68816, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6563 - accuracy: 0.7802 - val_loss: 0.6882 - val_accuracy: 0.7780
# Epoch 8/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.5396 - accuracy: 0.8182
# Epoch 00008: val_loss improved from 0.68816 to 0.55544, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 0.5349 - accuracy: 0.8211 - val_loss: 0.5554 - val_accuracy: 0.8415
# Epoch 9/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.4184 - accuracy: 0.8551
# Epoch 00009: val_loss improved from 0.55544 to 0.53272, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.4152 - accuracy: 0.8547 - val_loss: 0.5327 - val_accuracy: 0.8512
# Epoch 10/100
# 51/52 [============================>.] - ETA: 0s - loss: 0.3417 - accuracy: 0.8775
# Epoch 00010: val_loss improved from 0.53272 to 0.52522, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3415 - accuracy: 0.8779 - val_loss: 0.5252 - val_accuracy: 0.8341
# Epoch 11/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.2975 - accuracy: 0.8974
# Epoch 00011: val_loss did not improve from 0.52522
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2936 - accuracy: 0.8974 - val_loss: 0.7255 - val_accuracy: 0.8293
# Epoch 12/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.2833 - accuracy: 0.9023
# Epoch 00012: val_loss improved from 0.52522 to 0.47528, saving model to /content/h5_models/best_model_3_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2838 - accuracy: 0.9011 - val_loss: 0.4753 - val_accuracy: 0.8634
# Epoch 13/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.2343 - accuracy: 0.9156
# Epoch 00013: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2409 - accuracy: 0.9121 - val_loss: 0.4841 - val_accuracy: 0.8561
# Epoch 14/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1841 - accuracy: 0.9254
# Epoch 00014: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1842 - accuracy: 0.9267 - val_loss: 0.6277 - val_accuracy: 0.8512
# Epoch 15/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.1574 - accuracy: 0.9488
# Epoch 00015: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1592 - accuracy: 0.9481 - val_loss: 0.5318 - val_accuracy: 0.8585
# Epoch 16/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1616 - accuracy: 0.9432
# Epoch 00016: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1628 - accuracy: 0.9438 - val_loss: 0.6088 - val_accuracy: 0.8268
# Epoch 17/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1505 - accuracy: 0.9471
# Epoch 00017: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1520 - accuracy: 0.9463 - val_loss: 0.5432 - val_accuracy: 0.8634
# Epoch 18/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1144 - accuracy: 0.9556
# Epoch 00018: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1138 - accuracy: 0.9560 - val_loss: 0.5719 - val_accuracy: 0.8610
# Epoch 19/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0936 - accuracy: 0.9681
# Epoch 00019: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0944 - accuracy: 0.9670 - val_loss: 0.6647 - val_accuracy: 0.8634
# Epoch 20/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.0863 - accuracy: 0.9688
# Epoch 00020: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0895 - accuracy: 0.9670 - val_loss: 0.7882 - val_accuracy: 0.8390
# Epoch 21/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.0885 - accuracy: 0.9655
# Epoch 00021: val_loss did not improve from 0.47528
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0878 - accuracy: 0.9652 - val_loss: 0.6710 - val_accuracy: 0.8805
# Epoch 22/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0538 - accuracy: 0.9853
# Epoch 00022: val_loss did not improve from 0.47528
# Epoch 21: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0548 - accuracy: 0.9841 - val_loss: 0.6982 - val_accuracy: 0.8561
# **********model_4*********
# random_state: 1485
# Epoch 1/100
# 50/52 [===========================>..] - ETA: 0s - loss: 2.3034 - accuracy: 0.1131
# Epoch 00001: val_loss improved from inf to 2.29524, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 14ms/step - loss: 2.3034 - accuracy: 0.1123 - val_loss: 2.2952 - val_accuracy: 0.1024
# Epoch 2/100
# 50/52 [===========================>..] - ETA: 0s - loss: 2.1762 - accuracy: 0.1863
# Epoch 00002: val_loss improved from 2.29524 to 1.92384, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1730 - accuracy: 0.1874 - val_loss: 1.9238 - val_accuracy: 0.3488
# Epoch 3/100
# 49/52 [===========================>..] - ETA: 0s - loss: 1.7987 - accuracy: 0.3718
# Epoch 00003: val_loss improved from 1.92384 to 1.45418, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.7908 - accuracy: 0.3761 - val_loss: 1.4542 - val_accuracy: 0.4927
# Epoch 4/100
# 49/52 [===========================>..] - ETA: 0s - loss: 1.3661 - accuracy: 0.5497
# Epoch 00004: val_loss improved from 1.45418 to 1.09485, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 1.3608 - accuracy: 0.5525 - val_loss: 1.0948 - val_accuracy: 0.6390
# Epoch 5/100
# 49/52 [===========================>..] - ETA: 0s - loss: 1.0434 - accuracy: 0.6448
# Epoch 00005: val_loss improved from 1.09485 to 0.86651, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 13ms/step - loss: 1.0294 - accuracy: 0.6514 - val_loss: 0.8665 - val_accuracy: 0.7439
# Epoch 6/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.7618 - accuracy: 0.7439
# Epoch 00006: val_loss improved from 0.86651 to 0.73741, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.7605 - accuracy: 0.7448 - val_loss: 0.7374 - val_accuracy: 0.7707
# Epoch 7/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.6506 - accuracy: 0.7806
# Epoch 00007: val_loss improved from 0.73741 to 0.66569, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6411 - accuracy: 0.7833 - val_loss: 0.6657 - val_accuracy: 0.7902
# Epoch 8/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.5403 - accuracy: 0.8145
# Epoch 00008: val_loss did not improve from 0.66569
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5434 - accuracy: 0.8132 - val_loss: 0.6954 - val_accuracy: 0.7854
# Epoch 9/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.3993 - accuracy: 0.8642
# Epoch 00009: val_loss improved from 0.66569 to 0.53183, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 16ms/step - loss: 0.3986 - accuracy: 0.8632 - val_loss: 0.5318 - val_accuracy: 0.8366
# Epoch 10/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.3548 - accuracy: 0.8807
# Epoch 00010: val_loss did not improve from 0.53183
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3482 - accuracy: 0.8834 - val_loss: 0.6336 - val_accuracy: 0.8171
# Epoch 11/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.3066 - accuracy: 0.8925
# Epoch 00011: val_loss did not improve from 0.53183
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3078 - accuracy: 0.8926 - val_loss: 0.5367 - val_accuracy: 0.8341
# Epoch 12/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.2801 - accuracy: 0.9044
# Epoch 00012: val_loss improved from 0.53183 to 0.51105, saving model to /content/h5_models/best_model_4_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2761 - accuracy: 0.9054 - val_loss: 0.5111 - val_accuracy: 0.8439
# Epoch 13/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1961 - accuracy: 0.9323
# Epoch 00013: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1962 - accuracy: 0.9328 - val_loss: 0.5991 - val_accuracy: 0.8122
# Epoch 14/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.2014 - accuracy: 0.9280
# Epoch 00014: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2026 - accuracy: 0.9267 - val_loss: 0.5599 - val_accuracy: 0.8659
# Epoch 15/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1358 - accuracy: 0.9499
# Epoch 00015: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1349 - accuracy: 0.9499 - val_loss: 0.6022 - val_accuracy: 0.8659
# Epoch 16/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1271 - accuracy: 0.9557
# Epoch 00016: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1328 - accuracy: 0.9530 - val_loss: 0.6848 - val_accuracy: 0.8610
# Epoch 17/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1085 - accuracy: 0.9605
# Epoch 00017: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1057 - accuracy: 0.9615 - val_loss: 0.6783 - val_accuracy: 0.8561
# Epoch 18/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0934 - accuracy: 0.9688
# Epoch 00018: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0917 - accuracy: 0.9695 - val_loss: 0.6591 - val_accuracy: 0.8415
# Epoch 19/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0958 - accuracy: 0.9663
# Epoch 00019: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0953 - accuracy: 0.9664 - val_loss: 0.5609 - val_accuracy: 0.8512
# Epoch 20/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1140 - accuracy: 0.9570
# Epoch 00020: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1193 - accuracy: 0.9548 - val_loss: 0.5304 - val_accuracy: 0.8561
# Epoch 21/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.0760 - accuracy: 0.9727
# Epoch 00021: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0756 - accuracy: 0.9719 - val_loss: 0.7172 - val_accuracy: 0.8488
# Epoch 22/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.0914 - accuracy: 0.9721
# Epoch 00022: val_loss did not improve from 0.51105
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0866 - accuracy: 0.9737 - val_loss: 0.7062 - val_accuracy: 0.8634
# Epoch 23/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0419 - accuracy: 0.9841
# Epoch 00023: val_loss did not improve from 0.51105
# Epoch 22: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0439 - accuracy: 0.9835 - val_loss: 0.6873 - val_accuracy: 0.8659
# **********model_5*********
# random_state: 1880
# Epoch 1/100
# 48/52 [==========================>...] - ETA: 0s - loss: 2.3029 - accuracy: 0.1100
# Epoch 00001: val_loss improved from inf to 2.28405, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 15ms/step - loss: 2.3022 - accuracy: 0.1099 - val_loss: 2.2841 - val_accuracy: 0.1293
# Epoch 2/100
# 47/52 [==========================>...] - ETA: 0s - loss: 2.1648 - accuracy: 0.2074
# Epoch 00002: val_loss improved from 2.28405 to 1.88559, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 2.1409 - accuracy: 0.2137 - val_loss: 1.8856 - val_accuracy: 0.2805
# Epoch 3/100
# 48/52 [==========================>...] - ETA: 0s - loss: 1.8033 - accuracy: 0.3568
# Epoch 00003: val_loss improved from 1.88559 to 1.46134, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.7769 - accuracy: 0.3663 - val_loss: 1.4613 - val_accuracy: 0.4902
# Epoch 4/100
# 49/52 [===========================>..] - ETA: 0s - loss: 1.3311 - accuracy: 0.5548
# Epoch 00004: val_loss improved from 1.46134 to 1.05433, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.3248 - accuracy: 0.5592 - val_loss: 1.0543 - val_accuracy: 0.6171
# Epoch 5/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.9086 - accuracy: 0.6941
# Epoch 00005: val_loss improved from 1.05433 to 0.77505, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 13ms/step - loss: 0.8914 - accuracy: 0.6990 - val_loss: 0.7750 - val_accuracy: 0.7488
# Epoch 6/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.7025 - accuracy: 0.7754
# Epoch 00006: val_loss improved from 0.77505 to 0.67855, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 13ms/step - loss: 0.7019 - accuracy: 0.7729 - val_loss: 0.6785 - val_accuracy: 0.7707
# Epoch 7/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.5727 - accuracy: 0.8125
# Epoch 00007: val_loss improved from 0.67855 to 0.67639, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5712 - accuracy: 0.8132 - val_loss: 0.6764 - val_accuracy: 0.7732
# Epoch 8/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.4654 - accuracy: 0.8489
# Epoch 00008: val_loss improved from 0.67639 to 0.58106, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 0.4739 - accuracy: 0.8480 - val_loss: 0.5811 - val_accuracy: 0.8098
# Epoch 9/100
# 52/52 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8663
# Epoch 00009: val_loss did not improve from 0.58106
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3968 - accuracy: 0.8663 - val_loss: 0.6341 - val_accuracy: 0.8122
# Epoch 10/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.3520 - accuracy: 0.8810
# Epoch 00010: val_loss improved from 0.58106 to 0.51349, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 15ms/step - loss: 0.3546 - accuracy: 0.8803 - val_loss: 0.5135 - val_accuracy: 0.8098
# Epoch 11/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.3133 - accuracy: 0.8956
# Epoch 00011: val_loss improved from 0.51349 to 0.50786, saving model to /content/h5_models/best_model_5_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3111 - accuracy: 0.8968 - val_loss: 0.5079 - val_accuracy: 0.8317
# Epoch 12/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.2187 - accuracy: 0.9309
# Epoch 00012: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2233 - accuracy: 0.9274 - val_loss: 0.6365 - val_accuracy: 0.8220
# Epoch 13/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1934 - accuracy: 0.9311
# Epoch 00013: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1982 - accuracy: 0.9286 - val_loss: 0.6517 - val_accuracy: 0.8122
# Epoch 14/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.2042 - accuracy: 0.9273
# Epoch 00014: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2078 - accuracy: 0.9255 - val_loss: 0.5184 - val_accuracy: 0.8317
# Epoch 15/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1511 - accuracy: 0.9458
# Epoch 00015: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1472 - accuracy: 0.9475 - val_loss: 0.7518 - val_accuracy: 0.8268
# Epoch 16/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1233 - accuracy: 0.9531
# Epoch 00016: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1232 - accuracy: 0.9536 - val_loss: 0.7717 - val_accuracy: 0.8366
# Epoch 17/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1262 - accuracy: 0.9534
# Epoch 00017: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1271 - accuracy: 0.9542 - val_loss: 0.5995 - val_accuracy: 0.8317
# Epoch 18/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.1092 - accuracy: 0.9620
# Epoch 00018: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1127 - accuracy: 0.9591 - val_loss: 0.6831 - val_accuracy: 0.8244
# Epoch 19/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1722 - accuracy: 0.9401
# Epoch 00019: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1695 - accuracy: 0.9402 - val_loss: 0.6481 - val_accuracy: 0.8537
# Epoch 20/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0778 - accuracy: 0.9726
# Epoch 00020: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0781 - accuracy: 0.9731 - val_loss: 0.7164 - val_accuracy: 0.8463
# Epoch 21/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0915 - accuracy: 0.9713
# Epoch 00021: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1073 - accuracy: 0.9676 - val_loss: 0.6947 - val_accuracy: 0.8390
# Epoch 22/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0545 - accuracy: 0.9794
# Epoch 00022: val_loss did not improve from 0.50786
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0540 - accuracy: 0.9792 - val_loss: 0.5980 - val_accuracy: 0.8488
# Epoch 23/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0249 - accuracy: 0.9936
# Epoch 00023: val_loss did not improve from 0.50786
# Epoch 22: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0255 - accuracy: 0.9933 - val_loss: 0.7359 - val_accuracy: 0.8415
# **********model_6*********
# random_state: 665
# Epoch 1/100
# 47/52 [==========================>...] - ETA: 0s - loss: 2.3057 - accuracy: 0.1104
# Epoch 00001: val_loss improved from inf to 2.29707, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 15ms/step - loss: 2.3046 - accuracy: 0.1136 - val_loss: 2.2971 - val_accuracy: 0.0902
# Epoch 2/100
# 49/52 [===========================>..] - ETA: 0s - loss: 2.2784 - accuracy: 0.1499
# Epoch 00002: val_loss improved from 2.29707 to 2.15633, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2724 - accuracy: 0.1532 - val_loss: 2.1563 - val_accuracy: 0.1659
# Epoch 3/100
# 47/52 [==========================>...] - ETA: 0s - loss: 1.9388 - accuracy: 0.3065
# Epoch 00003: val_loss improved from 2.15633 to 1.60232, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.9170 - accuracy: 0.3156 - val_loss: 1.6023 - val_accuracy: 0.4488
# Epoch 4/100
# 48/52 [==========================>...] - ETA: 0s - loss: 1.5276 - accuracy: 0.4850
# Epoch 00004: val_loss improved from 1.60232 to 1.15644, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 1.5115 - accuracy: 0.4902 - val_loss: 1.1564 - val_accuracy: 0.6366
# Epoch 5/100
# 50/52 [===========================>..] - ETA: 0s - loss: 1.1172 - accuracy: 0.6256
# Epoch 00005: val_loss improved from 1.15644 to 0.99643, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1186 - accuracy: 0.6252 - val_loss: 0.9964 - val_accuracy: 0.6610
# Epoch 6/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.8575 - accuracy: 0.7168
# Epoch 00006: val_loss improved from 0.99643 to 0.69503, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.8565 - accuracy: 0.7161 - val_loss: 0.6950 - val_accuracy: 0.7780
# Epoch 7/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.6632 - accuracy: 0.7756
# Epoch 00007: val_loss improved from 0.69503 to 0.57957, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6661 - accuracy: 0.7735 - val_loss: 0.5796 - val_accuracy: 0.8293
# Epoch 8/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.5349 - accuracy: 0.8185
# Epoch 00008: val_loss improved from 0.57957 to 0.51686, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 0.5376 - accuracy: 0.8193 - val_loss: 0.5169 - val_accuracy: 0.8366
# Epoch 9/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.4402 - accuracy: 0.8501
# Epoch 00009: val_loss did not improve from 0.51686
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4418 - accuracy: 0.8510 - val_loss: 0.5403 - val_accuracy: 0.8317
# Epoch 10/100
# 52/52 [==============================] - ETA: 0s - loss: 0.3747 - accuracy: 0.8651
# Epoch 00010: val_loss improved from 0.51686 to 0.48273, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 16ms/step - loss: 0.3747 - accuracy: 0.8651 - val_loss: 0.4827 - val_accuracy: 0.8610
# Epoch 11/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.3118 - accuracy: 0.8913
# Epoch 00011: val_loss did not improve from 0.48273
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3098 - accuracy: 0.8926 - val_loss: 0.5458 - val_accuracy: 0.8488
# Epoch 12/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.2915 - accuracy: 0.8896
# Epoch 00012: val_loss improved from 0.48273 to 0.46521, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2920 - accuracy: 0.8926 - val_loss: 0.4652 - val_accuracy: 0.8488
# Epoch 13/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.2147 - accuracy: 0.9247
# Epoch 00013: val_loss did not improve from 0.46521
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2140 - accuracy: 0.9249 - val_loss: 0.5768 - val_accuracy: 0.8537
# Epoch 14/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1740 - accuracy: 0.9401
# Epoch 00014: val_loss did not improve from 0.46521
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1767 - accuracy: 0.9383 - val_loss: 0.4691 - val_accuracy: 0.8585
# Epoch 15/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.2095 - accuracy: 0.9237
# Epoch 00015: val_loss improved from 0.46521 to 0.41969, saving model to /content/h5_models/best_model_6_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2112 - accuracy: 0.9237 - val_loss: 0.4197 - val_accuracy: 0.8683
# Epoch 16/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1353 - accuracy: 0.9544
# Epoch 00016: val_loss did not improve from 0.41969
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1355 - accuracy: 0.9548 - val_loss: 0.4334 - val_accuracy: 0.8976
# Epoch 17/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1116 - accuracy: 0.9583
# Epoch 00017: val_loss did not improve from 0.41969
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1135 - accuracy: 0.9573 - val_loss: 0.5629 - val_accuracy: 0.8707
# Epoch 18/100
# 51/52 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9534
# Epoch 00018: val_loss did not improve from 0.41969
# ...
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1061 - accuracy: 0.9683 - val_loss: 0.5151 - val_accuracy: 0.8756
# Epoch 19/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0902 - accuracy: 0.9650
# Epoch 00019: val_loss did not improve from 0.35175
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0899 - accuracy: 0.9652 - val_loss: 0.5311 - val_accuracy: 0.8659
# Epoch 20/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1169 - accuracy: 0.9611
# Epoch 00020: val_loss did not improve from 0.35175
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1159 - accuracy: 0.9615 - val_loss: 0.5172 - val_accuracy: 0.8707
# Epoch 21/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0614 - accuracy: 0.9783
# Epoch 00021: val_loss did not improve from 0.35175
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0598 - accuracy: 0.9786 - val_loss: 0.4674 - val_accuracy: 0.8927
# Epoch 22/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0337 - accuracy: 0.9872
# Epoch 00022: val_loss did not improve from 0.35175
# Epoch 21: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0339 - accuracy: 0.9878 - val_loss: 0.5175 - val_accuracy: 0.8756
# **********model_8*********
# random_state: 1653
# Epoch 1/100
# 48/52 [==========================>...] - ETA: 0s - loss: 2.3047 - accuracy: 0.1074
# Epoch 00001: val_loss improved from inf to 2.30758, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 14ms/step - loss: 2.3032 - accuracy: 0.1117 - val_loss: 2.3076 - val_accuracy: 0.1293
# Epoch 2/100
# 50/52 [===========================>..] - ETA: 0s - loss: 2.2494 - accuracy: 0.1556
# Epoch 00002: val_loss improved from 2.30758 to 2.08322, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2468 - accuracy: 0.1593 - val_loss: 2.0832 - val_accuracy: 0.2585
# Epoch 3/100
# 48/52 [==========================>...] - ETA: 0s - loss: 1.9425 - accuracy: 0.3008
# Epoch 00003: val_loss improved from 2.08322 to 1.67359, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.9330 - accuracy: 0.3077 - val_loss: 1.6736 - val_accuracy: 0.4122
# Epoch 4/100
# 49/52 [===========================>..] - ETA: 0s - loss: 1.5164 - accuracy: 0.4841
# Epoch 00004: val_loss improved from 1.67359 to 1.28851, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 25ms/step - loss: 1.5119 - accuracy: 0.4872 - val_loss: 1.2885 - val_accuracy: 0.6317
# Epoch 5/100
# 50/52 [===========================>..] - ETA: 0s - loss: 1.1236 - accuracy: 0.6212
# Epoch 00005: val_loss improved from 1.28851 to 0.88908, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1154 - accuracy: 0.6245 - val_loss: 0.8891 - val_accuracy: 0.7098
# Epoch 6/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.8318 - accuracy: 0.7369
# Epoch 00006: val_loss improved from 0.88908 to 0.65209, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8302 - accuracy: 0.7381 - val_loss: 0.6521 - val_accuracy: 0.7927
# Epoch 7/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.6436 - accuracy: 0.7874
# Epoch 00007: val_loss improved from 0.65209 to 0.61931, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 24ms/step - loss: 0.6355 - accuracy: 0.7894 - val_loss: 0.6193 - val_accuracy: 0.7927
# Epoch 8/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.5628 - accuracy: 0.8131
# Epoch 00008: val_loss improved from 0.61931 to 0.52510, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 24ms/step - loss: 0.5689 - accuracy: 0.8114 - val_loss: 0.5251 - val_accuracy: 0.8244
# Epoch 9/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.4560 - accuracy: 0.8531
# Epoch 00009: val_loss improved from 0.52510 to 0.43801, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.4518 - accuracy: 0.8547 - val_loss: 0.4380 - val_accuracy: 0.8244
# Epoch 10/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.3609 - accuracy: 0.8690
# Epoch 00010: val_loss did not improve from 0.43801
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3602 - accuracy: 0.8687 - val_loss: 0.4645 - val_accuracy: 0.8366
# Epoch 11/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.3335 - accuracy: 0.8900
# Epoch 00011: val_loss did not improve from 0.43801
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3337 - accuracy: 0.8889 - val_loss: 0.4542 - val_accuracy: 0.8415
# Epoch 12/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.2907 - accuracy: 0.9013
# Epoch 00012: val_loss improved from 0.43801 to 0.42205, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2894 - accuracy: 0.9023 - val_loss: 0.4220 - val_accuracy: 0.8659
# Epoch 13/100
# 51/52 [============================>.] - ETA: 0s - loss: 0.2363 - accuracy: 0.9173
# Epoch 00013: val_loss did not improve from 0.42205
# 52/52 [==============================] - 0s 10ms/step - loss: 0.2357 - accuracy: 0.9176 - val_loss: 0.4462 - val_accuracy: 0.8390
# Epoch 14/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.2251 - accuracy: 0.9238
# Epoch 00014: val_loss did not improve from 0.42205
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2182 - accuracy: 0.9255 - val_loss: 0.5931 - val_accuracy: 0.8366
# Epoch 15/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1925 - accuracy: 0.9362
# Epoch 00015: val_loss did not improve from 0.42205
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1899 - accuracy: 0.9371 - val_loss: 0.4360 - val_accuracy: 0.8488
# Epoch 16/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1265 - accuracy: 0.9515
# Epoch 00016: val_loss did not improve from 0.42205
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1263 - accuracy: 0.9512 - val_loss: 0.4836 - val_accuracy: 0.8585
# Epoch 17/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1391 - accuracy: 0.9481
# Epoch 00017: val_loss did not improve from 0.42205
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1367 - accuracy: 0.9493 - val_loss: 0.4480 - val_accuracy: 0.8756
# Epoch 18/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1391 - accuracy: 0.9577
# Epoch 00018: val_loss did not improve from 0.42205
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1402 - accuracy: 0.9554 - val_loss: 0.4638 - val_accuracy: 0.8732
# Epoch 19/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1066 - accuracy: 0.9669
# Epoch 00019: val_loss improved from 0.42205 to 0.38812, saving model to /content/h5_models/best_model_8_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1076 - accuracy: 0.9658 - val_loss: 0.3881 - val_accuracy: 0.8585
# Epoch 20/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1109 - accuracy: 0.9596
# Epoch 00020: val_loss did not improve from 0.38812
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1110 - accuracy: 0.9585 - val_loss: 0.6157 - val_accuracy: 0.8415
# Epoch 21/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.1190 - accuracy: 0.9628
# Epoch 00021: val_loss did not improve from 0.38812
# 52/52 [==============================] - 0s 10ms/step - loss: 0.1206 - accuracy: 0.9621 - val_loss: 0.4465 - val_accuracy: 0.8415
# Epoch 22/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1011 - accuracy: 0.9668
# Epoch 00022: val_loss did not improve from 0.38812
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1006 - accuracy: 0.9664 - val_loss: 0.4355 - val_accuracy: 0.8683
# Epoch 23/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1190 - accuracy: 0.9600
# Epoch 00023: val_loss did not improve from 0.38812
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1171 - accuracy: 0.9609 - val_loss: 0.4313 - val_accuracy: 0.8659
# Epoch 24/100
# 46/52 [=========================>....] - ETA: 0s - loss: 0.0568 - accuracy: 0.9776
# Epoch 00024: val_loss did not improve from 0.38812
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0601 - accuracy: 0.9768 - val_loss: 0.6214 - val_accuracy: 0.8610
# Epoch 25/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0787 - accuracy: 0.9756
# Epoch 00025: val_loss did not improve from 0.38812
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0771 - accuracy: 0.9762 - val_loss: 0.5341 - val_accuracy: 0.8707
# Epoch 26/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.0359 - accuracy: 0.9874
# Epoch 00026: val_loss did not improve from 0.38812
# Epoch 25: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0340 - accuracy: 0.9878 - val_loss: 0.5200 - val_accuracy: 0.8854
# **********model_9*********
# random_state: 1499
# Epoch 1/100
# 50/52 [===========================>..] - ETA: 0s - loss: 2.3003 - accuracy: 0.1244
# Epoch 00001: val_loss improved from inf to 2.29460, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 14ms/step - loss: 2.3002 - accuracy: 0.1245 - val_loss: 2.2946 - val_accuracy: 0.1171
# Epoch 2/100
# 49/52 [===========================>..] - ETA: 0s - loss: 2.2210 - accuracy: 0.1741
# Epoch 00002: val_loss improved from 2.29460 to 1.91287, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2087 - accuracy: 0.1758 - val_loss: 1.9129 - val_accuracy: 0.2951
# Epoch 3/100
# 48/52 [==========================>...] - ETA: 0s - loss: 1.7948 - accuracy: 0.3496
# Epoch 00003: val_loss improved from 1.91287 to 1.32315, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.7848 - accuracy: 0.3584 - val_loss: 1.3231 - val_accuracy: 0.5756
# Epoch 4/100
# 49/52 [===========================>..] - ETA: 0s - loss: 1.2879 - accuracy: 0.5555
# Epoch 00004: val_loss improved from 1.32315 to 1.03727, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 1.2829 - accuracy: 0.5574 - val_loss: 1.0373 - val_accuracy: 0.6512
# Epoch 5/100
# 51/52 [============================>.] - ETA: 0s - loss: 0.9369 - accuracy: 0.6844
# Epoch 00005: val_loss improved from 1.03727 to 0.75985, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 13ms/step - loss: 0.9404 - accuracy: 0.6838 - val_loss: 0.7598 - val_accuracy: 0.7366
# Epoch 6/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.7600 - accuracy: 0.7427
# Epoch 00006: val_loss improved from 0.75985 to 0.68019, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.7497 - accuracy: 0.7448 - val_loss: 0.6802 - val_accuracy: 0.7756
# Epoch 7/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.6066 - accuracy: 0.7962
# Epoch 00007: val_loss improved from 0.68019 to 0.56929, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6070 - accuracy: 0.7955 - val_loss: 0.5693 - val_accuracy: 0.8146
# Epoch 8/100
# 47/52 [==========================>...] - ETA: 0s - loss: 0.4928 - accuracy: 0.8324
# Epoch 00008: val_loss improved from 0.56929 to 0.46186, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 24ms/step - loss: 0.4893 - accuracy: 0.8315 - val_loss: 0.4619 - val_accuracy: 0.8341
# Epoch 9/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.4005 - accuracy: 0.8629
# Epoch 00009: val_loss did not improve from 0.46186
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4044 - accuracy: 0.8602 - val_loss: 0.6262 - val_accuracy: 0.7683
# Epoch 10/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.3453 - accuracy: 0.8776
# Epoch 00010: val_loss improved from 0.46186 to 0.44667, saving model to /content/h5_models/best_model_9_2020_9_17__13_22_25.h5
# 52/52 [==============================] - 1s 15ms/step - loss: 0.3509 - accuracy: 0.8742 - val_loss: 0.4467 - val_accuracy: 0.8488
# Epoch 11/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.3297 - accuracy: 0.8909
# Epoch 00011: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3250 - accuracy: 0.8913 - val_loss: 0.5063 - val_accuracy: 0.8220
# Epoch 12/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.2375 - accuracy: 0.9137
# Epoch 00012: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2360 - accuracy: 0.9145 - val_loss: 0.4643 - val_accuracy: 0.8390
# Epoch 13/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.2157 - accuracy: 0.9330
# Epoch 00013: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2172 - accuracy: 0.9316 - val_loss: 0.4613 - val_accuracy: 0.8610
# Epoch 14/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.2300 - accuracy: 0.9181
# Epoch 00014: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2325 - accuracy: 0.9170 - val_loss: 0.5206 - val_accuracy: 0.8439
# Epoch 15/100
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1622 - accuracy: 0.9440
# Epoch 00015: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1640 - accuracy: 0.9432 - val_loss: 0.5129 - val_accuracy: 0.8659
# Epoch 16/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.2247 - accuracy: 0.9312
# Epoch 00016: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2261 - accuracy: 0.9298 - val_loss: 0.4982 - val_accuracy: 0.8659
# Epoch 17/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1219 - accuracy: 0.9554
# Epoch 00017: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1213 - accuracy: 0.9567 - val_loss: 0.5755 - val_accuracy: 0.8512
# Epoch 18/100
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1285 - accuracy: 0.9563
# Epoch 00018: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1269 - accuracy: 0.9567 - val_loss: 0.5037 - val_accuracy: 0.8634
# Epoch 19/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.1158 - accuracy: 0.9547
# Epoch 00019: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1157 - accuracy: 0.9554 - val_loss: 0.4600 - val_accuracy: 0.8732
# Epoch 20/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0735 - accuracy: 0.9745
# Epoch 00020: val_loss did not improve from 0.44667
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0749 - accuracy: 0.9737 - val_loss: 0.4794 - val_accuracy: 0.8732
# Epoch 21/100
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0420 - accuracy: 0.9847
# Epoch 00021: val_loss did not improve from 0.44667
# Epoch 20: accuracy reached 0.98, terminating training
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0421 - accuracy: 0.9841 - val_loss: 0.5014 - val_accuracy: 0.8780

# %%
for i, model in enumerate(model_list):
    filename = f'best_model_{i}_{suffix}.h5'
    path = model_path / filename
    model.load_weights(path)

# %%
intermediate_layer_models = []
layer_name = 'feature_output'
for cnn_model in model_list:
  intermediate_layer_models.append(tf.keras.Model(inputs=cnn_model.input,
                                            outputs=cnn_model.get_layer(layer_name).output))

input_layer = tf.keras.Input((28, 28, 1))

avg_layer = [intermediate_model(input_layer) for intermediate_model in intermediate_layer_models]
output_layer = tf.keras.layers.average(avg_layer)

ensembled_feature_model = tf.keras.Model(inputs=input_layer, outputs=output_layer)

# %%
inputs = tf.keras.Input((28, 28, 1))

avg_layer = [cnn_model(inputs) for cnn_model in model_list]
output = tf.keras.layers.average(avg_layer)

ensembled_model = tf.keras.Model(inputs=inputs, outputs=output)

# %%
from xgboost import XGBClassifier
setup_data()
validation_split=.1

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=validation_split, random_state=random_state)

intermediate_output = ensembled_feature_model.predict(x_train)
train_labels = y_train

val_data = ensembled_feature_model.predict(x_val)
val_labels = y_val

xgbmodel = XGBClassifier(objective='multi:softprob', 
                      num_class= 10)
xgbmodel.fit(intermediate_output, train_labels)
xgbmodel.score(val_data, val_labels)

# %%
setup_data()

intermediate_test_output = ensembled_feature_model.predict(x_test)

submission_xgb = xgbmodel.predict(intermediate_test_output)
submission_xgb

# %%
from sklearn.naive_bayes import GaussianNB
setup_data()
validation_split=.1

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=validation_split, random_state=random_state)

intermediate_output = ensembled_feature_model.predict(x_train)
train_labels = y_train

val_data = ensembled_feature_model.predict(x_val)
val_labels = y_val

gnbmodel = GaussianNB().fit(intermediate_output, train_labels) 
gnbmodel.score(val_data, val_labels)
# Out:
# 0.8536585365853658

# %%
setup_data()

validation_split = 0.2

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=validation_split, random_state=2020)

intermediate_output = ensembled_feature_model(x_val)

xgb_proba = xgbmodel.predict_proba(intermediate_output)
gnb_proba = gnbmodel.predict_proba(intermediate_output)
ens_proba = ensembled_model.predict(x_val)

y_pred = np.add(np.add(xgb_proba, gnb_proba), ens_proba).argmax(axis=-1)
y_true = y_val

mask = y_pred == y_true
f'val_acuracy={(len(y_true[mask]) / len(y_true)):.4f}'
# Out:
# 'val_acuracy=0.9951'

# %%
from sklearn.metrics import classification_report

setup_data()
intermediate_output = ensembled_feature_model(x_train)

xgb_proba = xgbmodel.predict_proba(intermediate_output)
gnb_proba = gnbmodel.predict_proba(intermediate_output)
ens_proba = ensembled_model.predict(x_train)

y_pred = np.add(np.add(xgb_proba, gnb_proba), ens_proba).argmax(axis=-1)
y_true = y_train

cls_report = classification_report(
    y_true=y_true,
    y_pred=y_pred,
    output_dict=True,
    labels=np.arange(10)
)
cls_report
# Out:
# {'0': {'f1-score': 1.0, 'precision': 1.0, 'recall': 1.0, 'support': 191},
#  '1': {'f1-score': 0.995049504950495,
#   'precision': 0.995049504950495,
#   'recall': 0.995049504950495,
#   'support': 202},
#  '2': {'f1-score': 0.9956896551724138,
#   'precision': 1.0,
#   'recall': 0.9914163090128756,
#   'support': 233},
#  '3': {'f1-score': 0.9927007299270073,
#   'precision': 0.9902912621359223,
#   'recall': 0.9951219512195122,
#   'support': 205},
#  '4': {'f1-score': 0.9783132530120482,
#   'precision': 0.9759615384615384,
#   'recall': 0.9806763285024155,
#   'support': 207},
#  '5': {'f1-score': 0.9866071428571429,
#   'precision': 0.9910313901345291,
#   'recall': 0.9822222222222222,
#   'support': 225},
#  '6': {'f1-score': 0.9905660377358491,
#   'precision': 0.9905660377358491,
#   'recall': 0.9905660377358491,
#   'support': 212},
#  '7': {'f1-score': 1.0, 'precision': 1.0, 'recall': 1.0, 'support': 194},
#  '8': {'f1-score': 0.9889502762430938,
#   'precision': 0.9944444444444445,
#   'recall': 0.9835164835164835,
#   'support': 182},
#  '9': {'f1-score': 0.9899497487437185,
#   'precision': 0.9800995024875622,
#   'recall': 1.0,
#   'support': 197},
#  'accuracy': 0.99169921875,
#  'macro avg': {'f1-score': 0.9917826348641767,
#   'precision': 0.991744368035034,
#   'recall': 0.9918568837159853,
#   'support': 2048},
#  'weighted avg': {'f1-score': 0.9917020705982987,
#   'precision': 0.9917403812786183,
#   'recall': 0.99169921875,
#   'support': 2048}}

# %%
setup_data()
intermediate_output = ensembled_feature_model.predict(x_test)

xgb_proba = xgbmodel.predict_proba(intermediate_output)
gnb_proba = gnbmodel.predict_proba(intermediate_output)
ens_proba = ensembled_model.predict(x_test)

total_prediction = np.add(np.add(xgb_proba, ens_proba), gnb_proba).argmax(axis=-1)
total_prediction
# Out:
# array([6, 9, 3, ..., 6, 1, 0])

# %%
total_prediction = np.append(np.append(xgb_proba, gnb_proba, axis=1), ens_proba, axis=1).argmax(axis=-1) % 10

# %% [markdown]
# ## Evaluate with train.csv

# %%
setup_data()

def get_prediction(x):
  prediction = ensembled_model.predict(x)
  prediction = np.argmax(prediction, axis=-1)
  return prediction

y_pred = get_prediction(x_train)
y_true = y_train

# %%
from sklearn.metrics import classification_report

y_true = y_train
y_pred = total_prediction
cls_report = classification_report(
    y_true=y_true,
    y_pred=y_pred,
    output_dict=True,
    labels=np.arange(10)
)
cls_report

# %% [markdown]
# ## Save Submission CSV

# %%
submission_path = cwd / 'res/submission.csv'
submission_csv = pd.read_csv(submission_path)
submission_csv
# Out:
#           id  digit
# 0       2049      0
# 1       2050      0
# 2       2051      0
# 3       2052      0
# 4       2053      0
# ...      ...    ...
# 20475  22524      0
# 20476  22525      0
# 20477  22526      0
# 20478  22527      0
# 20479  22528      0
#
# [20480 rows x 2 columns]

# %%
setup_data()

submission_csv['digit'] = total_prediction

# %%
csv_path = cwd / 'csvs'
if not csv_path.exists():
  os.mkdir(csv_path)
filename = f'submission_{suffix}_2.csv'
path = csv_path / filename

f = open(cwd / 'log.txt', 'a')
f.write(f'{suffix} == {cls_report}\n')
f.close()

submission_csv.to_csv(path, index=False)
submission_csv = pd.read_csv(path)
submission_csv
# Out:
#           id  digit
# 0       2049      6
# 1       2050      9
# 2       2051      3
# 3       2052      0
# 4       2053      3
# ...      ...    ...
# 20475  22524      4
# 20476  22525      1
# 20477  22526      6
# 20478  22527      1
# 20479  22528      0
#
# [20480 rows x 2 columns]

# %%
f'submission_{suffix}.csv'
# Out:
# 'submission_2020_9_14__7_45_1.csv'

# %% [markdown]
# ## Propagating labels of test.csv from CNN Model

# %%
train_xs, train_ys = [], []
x_vals, y_vals = [], []

for i, _ in enumerate(model_list):
  setup_data()
  batch_size = 32
  np.random.shuffle(x_test)

  n_pick = int(len(x_train) * 2)
  n_pick = np.random.choice(len(x_test), n_pick)
  x_test = x_test[n_pick]
  y_test = get_prediction(x_test)

  picks = np.random.choice(len(x_train), int(len(x_train) * .5), replace=False)

  x_val = x_train[picks]
  y_val = y_train[picks]
  x_train = np.delete(x_train, picks, axis=0)
  y_train = np.delete(y_train, picks, axis=0)

  train_x = np.append(x_train, x_test, axis=0)
  train_y = np.append(y_train, y_test, axis=0)

  train_xs.append(train_x)
  train_ys.append(train_y)

  x_vals.append(x_val)
  y_vals.append(y_val)

  print(train_x.shape, train_y.shape, x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_val.shape, y_val.shape)

# %%
n_ensemble = 20

for i in range(len(model_list)):  
  model_list[i] = CNN(layer=3)
  print(f'**********model_{i}*********')
  filename = f'final_model_{i}_{suffix}.h5'
  path = model_path / filename

  print(train_x.shape, train_y.shape, x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_val.shape, y_val.shape)

  mc = ModelCheckpoint(path, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
  stop_training = StopTraining(baseline=0.99)
  history = model_list[i].fit(x = train_xs[i], y = train_ys[i], epochs = epochs, batch_size = batch_size,
                      shuffle = True, validation_data = (x_vals[i], y_vals[i]), callbacks = [mc, stop_training, reduceLR],
                      verbose=2)

# %%
setup_data()

def get_prediction(x):
    global model_list    
    predictions = []
    for i, model in enumerate(model_list):
        model_path = cwd
        filename = f'final_model_{i}_{suffix}.h5'
        path = model_path / filename
        model.load_weights(path)
        result = model.predict(x)
        predictions.append(result)
    predictions = np.array(predictions)
    y_pred = predictions.sum(axis=0).argmax(axis=1)
    return y_pred

y_pred = get_prediction(x_train)
y_true = y_train

# %%
from sklearn.metrics import classification_report

cls_report = classification_report(
    y_true=y_true,
    y_pred=y_pred,
    output_dict=True,
    labels=np.arange(10)
)
cls_report

# %%
submission_path = cwd / 'res/submission.csv'
submission_csv = pd.read_csv(submission_path)
submission_csv

# %%
setup_data()

digits = get_prediction(x_test)
submission_csv['digit'] = digits

# %%
csv_path = cwd / 'csvs'
if not csv_path.exists():
  os.mkdir(csv_path)
filename = f'submission_{suffix}_final.csv'
path = csv_path / filename

f = open(cwd / 'log.txt', 'a')
f.write(f'{year}-{month}-{day} {hour}:{minute}:{second} == {cls_report}\n')
f.close()

submission_csv.to_csv(path, index=False)
submission_csv = pd.read_csv(path)
submission_csv

# %%
filename
